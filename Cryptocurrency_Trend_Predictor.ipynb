# %%
pip install pycoingecko
# Out:
# Requirement already satisfied: pycoingecko in /usr/local/lib/python3.10/dist-packages (3.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pycoingecko) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pycoingecko) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pycoingecko) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pycoingecko) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pycoingecko) (2023.11.17)

# %% [markdown]
# CoinGeckoAPI updates every 5 minutes

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly) (23.2)

# %%
from pycoingecko import CoinGeckoAPI                    #API where we are deriving the crypto data
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import requests
from statsmodels.tsa.arima.model import ARIMA           #Time-series machine learning model
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression       #Linear reggression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor        #Random Forest and GB Regressor
from sklearn.metrics import accuracy_score

# %%
cg = CoinGeckoAPI()

# %% [markdown]
# Taking the latest information of bitcoin

# %%
# Get information about the top 10 cryptocurrencies
top_10_coins = cg.get_coins_markets(vs_currency='usd', order='market_cap_desc', per_page=10, page=1)

# Print information about the top 10 cryptocurrencies
for index, coin in enumerate(top_10_coins, start=1):
    coin_name = coin['name']
    coin_symbol = coin['symbol']
    coin_market_cap = coin['market_cap']
    coin_price = coin['current_price']

    print(f"{index}. {coin_name} ({coin_symbol}) - Market Cap: ${coin_market_cap:,}, Price: ${coin_price:.2f}")
# Out:
# 1. Bitcoin (btc) - Market Cap: $806,866,398,297, Price: $41341.00
# 2. Ethereum (eth) - Market Cap: $262,813,437,611, Price: $2191.21
# 3. Tether (usdt) - Market Cap: $90,543,075,585, Price: $1.00
# 4. BNB (bnb) - Market Cap: $39,251,159,650, Price: $255.72
# 5. XRP (xrp) - Market Cap: $33,313,305,356, Price: $0.62
# 6. Solana (sol) - Market Cap: $28,873,408,786, Price: $67.92
# 7. USDC (usdc) - Market Cap: $24,032,959,977, Price: $1.00
# 8. Lido Staked Ether (steth) - Market Cap: $20,148,563,689, Price: $2189.72
# 9. Cardano (ada) - Market Cap: $19,909,338,839, Price: $0.57
# 10. Avalanche (avax) - Market Cap: $13,677,483,269, Price: $37.62

# %%
top_10_coins = cg.get_coins_markets(vs_currency='usd', order='market_cap_desc', per_page=10, page=1)

# Extract the IDs of the top 10 cryptocurrencies
top_10_coin_ids = [coin['id'] for coin in top_10_coins]

# Print the IDs
print("Top 10 Cryptocurrency IDs:")
for coin_id in top_10_coin_ids:
    print(coin_id)
# Out:
# Top 10 Cryptocurrency IDs:
# bitcoin
# ethereum
# tether
# binancecoin
# ripple
# solana
# usd-coin
# staked-ether
# cardano
# avalanche-2

# %%
btc = cg.get_coin_market_chart_by_id(id='bitcoin', vs_currency='USD', days=90)

# %%
bitcoin_data = pd.DataFrame(btc['prices'], columns = ['timestamp', 'price'])

# %%
bitcoin_data
# Out:
#           timestamp         price
# 0     1694638801518  26226.862816
# 1     1694642483410  26231.949378
# 2     1694646050908  26234.189828
# 3     1694649714172  26222.013304
# 4     1694653240839  26488.966008
# ...             ...           ...
# 2156  1702400406130  41301.185434
# 2157  1702404026095  40720.052616
# 2158  1702407609812  41251.165163
# 2159  1702411209758  41083.081025
# 2160  1702415632000  41286.271108
#
# [2161 rows x 2 columns]

# %% [markdown]
# Converting timestamp to datetime format

# %%
bitcoin_data['Date'] = pd.to_datetime(bitcoin_data['timestamp'], unit = 'ms')

# %%
bitcoin_data
# Out:
#           timestamp         price                    Date
# 0     1694638801518  26226.862816 2023-09-13 21:00:01.518
# 1     1694642483410  26231.949378 2023-09-13 22:01:23.410
# 2     1694646050908  26234.189828 2023-09-13 23:00:50.908
# 3     1694649714172  26222.013304 2023-09-14 00:01:54.172
# 4     1694653240839  26488.966008 2023-09-14 01:00:40.839
# ...             ...           ...                     ...
# 2156  1702400406130  41301.185434 2023-12-12 17:00:06.130
# 2157  1702404026095  40720.052616 2023-12-12 18:00:26.095
# 2158  1702407609812  41251.165163 2023-12-12 19:00:09.812
# 2159  1702411209758  41083.081025 2023-12-12 20:00:09.758
# 2160  1702415632000  41286.271108 2023-12-12 21:13:52.000
#
# [2161 rows x 3 columns]

# %% [markdown]
# Aggregating all the values on the basis of date and creating a new dataframe. We will use this for our prediction and visualization.

# %%
candlestick_data = bitcoin_data.groupby(bitcoin_data.Date.dt.date).aggregate({'price': {'max', 'min', 'first', 'last'}})

# %%
candlestick_data
# Out:
#                    price
#                     last         first           max           min
# Date
# 2023-09-13  26234.189828  26226.862816  26234.189828  26226.862816
# 2023-09-14  26615.532123  26222.013304  26751.796646  26193.031946
# 2023-09-15  26792.608825  26531.395566  26792.608825  26251.615685
# 2023-09-16  26566.033844  26610.403126  26704.253882  26471.093720
# 2023-09-17  26468.617802  26557.768692  26605.367472  26462.583232
# ...                  ...           ...           ...           ...
# 2023-12-08  44252.835095  43270.119560  44385.975286  43174.140967
# 2023-12-09  43908.530003  44158.481190  44290.263279  43824.945022
# 2023-12-10  43783.921845  43714.935354  43968.397400  43634.411927
# 2023-12-11  41259.309734  43757.959938  43757.959938  40753.097997
# 2023-12-12  41286.271108  41262.427743  42026.304644  40720.052616
#
# [91 rows x 4 columns]

# %%
candlestick_data.index
# Out:
# Index([2023-09-13, 2023-09-14, 2023-09-15, 2023-09-16, 2023-09-17, 2023-09-18,
#        2023-09-19, 2023-09-20, 2023-09-21, 2023-09-22, 2023-09-23, 2023-09-24,
#        2023-09-25, 2023-09-26, 2023-09-27, 2023-09-28, 2023-09-29, 2023-09-30,
#        2023-10-01, 2023-10-02, 2023-10-03, 2023-10-04, 2023-10-05, 2023-10-06,
#        2023-10-07, 2023-10-08, 2023-10-09, 2023-10-10, 2023-10-11, 2023-10-12,
#        2023-10-13, 2023-10-14, 2023-10-15, 2023-10-16, 2023-10-17, 2023-10-18,
#        2023-10-19, 2023-10-20, 2023-10-21, 2023-10-22, 2023-10-23, 2023-10-24,
#        2023-10-25, 2023-10-26, 2023-10-27, 2023-10-28, 2023-10-29, 2023-10-30,
#        2023-10-31, 2023-11-01, 2023-11-02, 2023-11-03, 2023-11-04, 2023-11-05,
#        2023-11-06, 2023-11-07, 2023-11-08, 2023-11-09, 2023-11-10, 2023-11-11,
#        2023-11-12, 2023-11-13, 2023-11-14, 2023-11-15, 2023-11-16, 2023-11-17,
#        2023-11-18, 2023-11-19, 2023-11-20, 2023-11-21, 2023-11-22, 2023-11-23,
#        2023-11-24, 2023-11-25, 2023-11-26, 2023-11-27, 2023-11-28, 2023-11-29,
#        2023-11-30, 2023-12-01, 2023-12-02, 2023-12-03, 2023-12-04, 2023-12-05,
#        2023-12-06, 2023-12-07, 2023-12-08, 2023-12-09, 2023-12-10, 2023-12-11,
#        2023-12-12],
#       dtype='object', name='Date')

# %%
fig = go.Figure(data=[go.Candlestick(x = candlestick_data.index,
                                     open = candlestick_data['price']['first'],
                                     low = candlestick_data['price']['min'],
                                     high = candlestick_data['price']['max'],
                                     close = candlestick_data['price']['last'])])

# %% [markdown]
# Visualization of Data.

# %%
fig.update_layout(title = 'Bitcoin prices over the last 90 days',
                  yaxis_title = 'Price (USD)',
                  xaxis_title = 'Date')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="22db7a47-3539-4706-90ae-f13217c0f70d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("22db7a47-3539-4706-90ae-f13217c0f70d")) {                    Plotly.newPlot(                        "22db7a47-3539-4706-90ae-f13217c0f70d",                        [{"close":[26234.18982796697,26615.532123428224,26792.60882462043,26566.033844441456,26468.617801591503,26867.0605755984,27200.83584839815,27110.600552890646,26589.232106802505,26582.589416632578,26575.52911690974,26503.235602590674,26287.076366997982,26151.495531909033,26288.209341200014,27013.05810967051,26896.650032793077,27007.09435594733,27958.086080312773,27548.852018252153,27317.95783922375,27749.3591623358,27467.11281497509,28015.369152584746,27974.7571037059,27919.889110632826,27600.1025698656,27453.037553654438,26782.107677394106,26741.573640176197,26811.460759785718,26851.366155439206,27128.978144491553,28515.420222673423,28400.423999371484,28348.72475198672,28667.75098162602,29656.162130353616,30018.49610114377,29990.24756414851,33264.32768202586,34080.896772114276,34579.238189685086,34249.251206485445,33816.06934849948,34113.21446355799,34726.40365909276,34491.04715056969,34600.234530905356,35242.42251914622,34784.75682861825,34628.64860018296,35082.47514376539,34948.9802272091,35139.54799649783,35402.32239721335,35873.224389464325,36661.211863449986,37388.482326184385,36896.46481244737,37160.19989130365,36556.12320473314,35600.915413431205,37761.00853505901,36235.00577174696,36546.96421848689,36532.153607590735,36960.80556076372,37469.61749158779,36482.32215297025,37447.704620725824,37315.61310063634,37757.677579908384,37760.10455520974,37646.91333313132,37069.97426871866,37823.821220234415,37798.33697303296,37766.35189696482,38721.55637643629,39375.159354813426,40071.671214636764,41925.569045271164,44313.5688067047,43634.9044842414,43166.048404404966,44252.83509521942,43908.53000269771,43783.921845319455,41259.3097335054,41286.271108285575],"high":[26234.18982796697,26751.79664567292,26792.60882462043,26704.25388242849,26605.36747233914,27394.588104693972,27289.4248902988,27318.242557709546,27115.846446970816,26688.33796153136,26615.098925655053,26657.753582685626,26357.55015326377,26347.306498337617,26805.628892226956,27146.515346023432,27151.16450461917,27075.965613822682,27958.086080312773,28493.813745265812,27665.63327626977,27749.3591623358,28002.696815579708,28141.091408717115,28019.428794289277,28088.344154516606,27984.53805572639,27710.146587078358,27461.472926157647,26900.51950068074,27013.47907381674,26923.38432031609,27196.298592542582,28535.955587851917,28576.711914963784,28767.30051705669,28819.438174975017,29902.333349112665,30191.974890550126,30130.605421637614,33264.32768202586,34606.40663867492,34977.14917229203,34799.81951265261,34214.93736870389,34227.92376720186,34763.44622176207,34679.85957555487,34640.077352659755,35280.800709488845,35752.93847887172,34924.05545044328,35082.47514376539,35285.45065247467,35223.49269149692,35871.27410920022,35873.224389464325,37883.291998751076,37388.482326184385,37344.249000720345,37198.72767934926,37253.190610682024,36740.39552999041,37761.00853505901,37903.66245166294,36551.34316496115,36746.60953633107,37030.31035337546,37641.00141735154,37561.27729892008,37554.982662585884,37642.766568877785,38189.655829505544,37842.74095748697,37812.43724553806,37514.914425042676,38261.22764442761,38329.03761090173,38049.71405708279,38879.988983613905,39680.220004704446,40071.671214636764,42008.48490210153,44313.5688067047,44123.75642200011,43985.76702287833,44385.97528580486,44290.2632794866,43968.39740026597,43757.959937619176,42026.30464430417],"low":[26226.862815769757,26193.031945995655,26251.615685201057,26471.0 ...

# %% [markdown]
# Machine Learning Model

# %% [markdown]
# Target : Closing Price
#
# Current Features : Date, Max Price, Min Price, Open Price, Close Price.
#
# To Find sentiment score and add that as a feature for the final machine learning model.

# %% [markdown]
# Taking the sentiment data from alternative.me

# %%
url = 'https://api.alternative.me/fng/?limit=91&date_format=cn'

r= requests.get(url)

# %%
r
# Out:
# <Response [200]>

# %%
data = r.json()

# %%
temp_df = pd.DataFrame(data['data'])

# %%
temp_df
# Out:
#    value value_classification   timestamp time_until_update
# 0     67                Greed  2023-12-12       -1702327307
# 1     74                Greed  2023-12-11               NaN
# 2     74                Greed  2023-12-10               NaN
# 3     73                Greed  2023-12-09               NaN
# 4     72                Greed  2023-12-08               NaN
# ..   ...                  ...         ...               ...
# 86    46                 Fear  2023-09-17               NaN
# 87    43                 Fear  2023-09-16               NaN
# 88    45                 Fear  2023-09-15               NaN
# 89    45                 Fear  2023-09-14               NaN
# 90    41                 Fear  2023-09-13               NaN
#
# [91 rows x 4 columns]

# %% [markdown]
# Rescaling sentiment from 0 - 100 to -1 to 1

# %%
temp_df['value'] = temp_df['value'].astype(int)

# %%
temp_df['timestamp'] = pd.to_datetime(temp_df['timestamp'])

# %%
temp_df
# Out:
#     value value_classification  timestamp time_until_update
# 0      67                Greed 2023-12-12       -1702327307
# 1      74                Greed 2023-12-11               NaN
# 2      74                Greed 2023-12-10               NaN
# 3      73                Greed 2023-12-09               NaN
# 4      72                Greed 2023-12-08               NaN
# ..    ...                  ...        ...               ...
# 86     46                 Fear 2023-09-17               NaN
# 87     43                 Fear 2023-09-16               NaN
# 88     45                 Fear 2023-09-15               NaN
# 89     45                 Fear 2023-09-14               NaN
# 90     41                 Fear 2023-09-13               NaN
#
# [91 rows x 4 columns]

# %%
temp_df.index = temp_df['timestamp']

# %%
temp_df
# Out:
#             value value_classification  timestamp time_until_update
# timestamp
# 2023-12-12     67                Greed 2023-12-12       -1702327307
# 2023-12-11     74                Greed 2023-12-11               NaN
# 2023-12-10     74                Greed 2023-12-10               NaN
# 2023-12-09     73                Greed 2023-12-09               NaN
# 2023-12-08     72                Greed 2023-12-08               NaN
# ...           ...                  ...        ...               ...
# 2023-09-17     46                 Fear 2023-09-17               NaN
# 2023-09-16     43                 Fear 2023-09-16               NaN
# 2023-09-15     45                 Fear 2023-09-15               NaN
# 2023-09-14     45                 Fear 2023-09-14               NaN
# 2023-09-13     41                 Fear 2023-09-13               NaN
#
# [91 rows x 4 columns]

# %% [markdown]
# Merging both dataframes to create our final dataset.

# %%
final_dataset = pd.merge(candlestick_data, temp_df, left_index=True, right_index=True, how='left')
# Out:
# <ipython-input-201-4db8d3883f85>:1: FutureWarning:
#
# merging between different levels is deprecated and will be removed in a future version. (2 levels on the left, 1 on the right)

# %%
final_dataset = final_dataset.iloc[:,:5]

# %%
final_dataset.columns = ['closing_price', 'max_price', 'min_price', 'opening_price', 'sentiment']

# %% [markdown]
# Normalizing the data

# %%
scaler = MinMaxScaler()

# %%
final_dataset_n = scaler.fit_transform(final_dataset)

# %%
final_dataset
# Out:
#             closing_price     max_price     min_price  opening_price  \
# Date
# 2023-09-13   26234.189828  26226.862816  26234.189828   26226.862816
# 2023-09-14   26615.532123  26222.013304  26751.796646   26193.031946
# 2023-09-15   26792.608825  26531.395566  26792.608825   26251.615685
# 2023-09-16   26566.033844  26610.403126  26704.253882   26471.093720
# 2023-09-17   26468.617802  26557.768692  26605.367472   26462.583232
# ...                   ...           ...           ...            ...
# 2023-12-08   44252.835095  43270.119560  44385.975286   43174.140967
# 2023-12-09   43908.530003  44158.481190  44290.263279   43824.945022
# 2023-12-10   43783.921845  43714.935354  43968.397400   43634.411927
# 2023-12-11   41259.309734  43757.959938  43757.959938   40753.097997
# 2023-12-12   41286.271108  41262.427743  42026.304644   40720.052616
#
#             sentiment
# Date
# 2023-09-13         41
# 2023-09-14         45
# 2023-09-15         45
# 2023-09-16         43
# 2023-09-17         46
# ...               ...
# 2023-12-08         72
# 2023-12-09         73
# 2023-12-10         74
# 2023-12-11         74
# 2023-12-12         67
#
# [91 rows x 5 columns]

# %% [markdown]
# Normalized dataset

# %%
final_dataset_n
# Out:
# array([[4.55313085e-03, 1.23123344e-03, 0.00000000e+00, 9.44617062e-03,
#         0.00000000e+00],
#        [2.55497588e-02, 9.61121689e-04, 2.85154768e-02, 7.54191212e-03,
#         1.17647059e-01],
#        [3.52995654e-02, 1.81933276e-02, 3.07638606e-02, 1.08394503e-02,
#         1.17647059e-01],
#        [2.28243938e-02, 2.25939501e-02, 2.58962985e-02, 2.31933423e-02,
#         5.88235294e-02],
#        [1.74606866e-02, 1.96622778e-02, 2.04485473e-02, 2.27143074e-02,
#         1.47058824e-01],
#        [3.93988634e-02, 1.76136534e-02, 6.39275007e-02, 2.23897793e-02,
#         1.47058824e-01],
#        [5.77764609e-02, 2.98937163e-02, 5.81339541e-02, 3.51121140e-02,
#         1.47058824e-01],
#        [5.28081242e-02, 5.61681293e-02, 5.97215482e-02, 4.93939447e-02,
#         1.76470588e-01],
#        [2.41016853e-02, 5.07465123e-02, 4.85713442e-02, 2.02345319e-02,
#         1.76470588e-01],
#        [2.37359402e-02, 1.98496909e-02, 2.50194745e-02, 2.67442015e-02,
#         5.88235294e-02],
#        [2.33472015e-02, 2.10101255e-02, 2.09846628e-02, 2.68783476e-02,
#         1.76470588e-01],
#        [1.93667356e-02, 2.05620793e-02, 2.33345505e-02, 2.18630176e-02,
#         8.82352941e-02],
#        [7.46505275e-03, 2.94235225e-03, 6.79604359e-03, 0.00000000e+00,
#         1.76470588e-01],
#        [0.00000000e+00, 5.13346026e-03, 6.23171041e-03, 2.95687985e-03,
#         1.47058824e-01],
#        [7.52743408e-03, 0.00000000e+00, 3.14811491e-02, 6.04185636e-03,
#         8.82352941e-02],
#        [4.74374574e-02, 8.09800283e-03, 5.02609245e-02, 1.60954406e-02,
#         1.47058824e-01],
#        [4.10280528e-02, 4.47960645e-02, 5.05170513e-02, 4.37367373e-02,
#         2.05882353e-01],
#        [4.71090944e-02, 3.96821031e-02, 4.63742692e-02, 4.71097259e-02,
#         1.76470588e-01],
#        [9.94705021e-02, 4.26161486e-02, 9.49711672e-02, 5.12686084e-02,
#         2.05882353e-01],
#        [7.69381593e-02, 9.81831417e-02, 1.24484940e-01, 7.55574472e-02,
#         2.64705882e-01],
#        [6.42251735e-02, 7.85523564e-02, 7.88596500e-02, 6.79155812e-02,
#         2.64705882e-01],
#        [8.79780412e-02, 6.80373377e-02, 8.34721927e-02, 7.09803217e-02,
#         2.35294118e-01],
#        [7.24376156e-02, 8.84136195e-02, 9.74288172e-02, 7.77925820e-02,
#         2.05882353e-01],
#        [1.02624496e-01, 6.85716819e-02, 1.05053114e-01, 6.66622973e-02,
#         2.64705882e-01],
#        [1.00388405e-01, 9.76643556e-02, 9.83505986e-02, 1.02313859e-01,
#         2.35294118e-01],
#        [9.73673849e-02, 9.87419624e-02, 1.02147215e-01, 9.97764422e-02,
#         2.64705882e-01],
#        [7.97600041e-02, 9.71022001e-02, 9.64284330e-02, 7.28951320e-02,
#         2.64705882e-01],
#        [7.16626347e-02, 7.73669560e-02, 8.13119328e-02, 7.00274431e-02,
#         2.64705882e-01],
#        [3.47213744e-02, 6.61417174e-02, 6.76122523e-02, 3.23737392e-02,
#         1.76470588e-01],
#        [3.24895787e-02, 3.75173009e-02, 3.67087675e-02, 3.16541368e-02,
#         1.17647059e-01],
#        [3.63375490e-02, 2.92072902e-02, 4.29318233e-02, 3.58969848e-02,
#         8.82352941e-02],
#        [3.85347319e-02, 3.65275735e-02, 3.79684133e-02, 4.31559776e-02,
#         1.76470588e-01],
#        [5.38199906e-02, 3.66735053e-02, 5.30035333e-02, 4.36421749e-02,
#         1.17647059e-01],
#        [1.30157205e-01, 5.26653652e-02, 1.26806576e-01, 6.14240656e-02,
#         1.76470588e-01],
#        [1.23825537e-01, 1.29236468e-01, 1.29051883e-01, 1.18183907e-01,
#         3.23529412e-01],
#        [1.20978987e-01, 1.23259342e-01, 1.39551599e-01, 1.20865268e-01,
#         2.64705882e-01],
#        [1.38544505e-01, 1.18275610e-01, 1.42423915e-01, 1.20715838e-01,
#         3.23529412e-01],
#        [1.92966218e-01, 1.39859040e-01, 2.02081692e-01, 1.45987418e-01,
#         3.52941176e-01],
#        [2.12916252e-01, 1.93421453e-01, 2.18038334e-01, 1.93296478e-01,
#         6.47058824e-01],
#        [2.11360893e-01, 2.06938515e-01, 2.14657429e-01, 2.10333330e-01,
#         3.52941176e-01],
#        [3.91631068e-01, 2.12469736e-01, 3.87297320e-01, 2.22917893e-01,
#         3.52941176e-01],
#        [4.36591193e-01, 3.75883316e-01, 4.61233790e-01, 3.88059087e-01,
#         7.35294118e-01],
#        [4.64029769e-01, 4.25648007e-01, 4.81658367e-01, 4.37524469e-01,
#         9.11764706e-01],
#        [4.45860753e-01, 4.61933510e-01, 4.71889099e-01, 4.34078594e-01,
#         8.82352941e-01],
#        [4.22009850e-01, 4.43902008e-01, 4.39667357e-01, 4.25026767e-01,
#         8.52941176e-01],
#        [4.38370599e-01, 4.28564884e-01, 4.40382791e-01, 4.41297605e-01,
#         7.05882353e-01],
#        [4.72132669e-01, 4.39344702e-01, 4.69885258e-01, 4.46013336e-01,
#         9.11764706e-01],
#        [4.59173988e-01, 4.63424176e-01, 4.65280386e-01, 4.59377082e-01,
#         7.94117647e-01],
#        [4.65185823e-01, 4.61721616e-01, 4.63088744e-01, 4.56161041e-01,
#         7.35294118e-01],
#        [5.00544561e-01, 4.71630949e-01, 4.98386834e-01, 4.61311273e-01,
#         7.35294118e-01],
#        [4.75345582e-01, 5.15363694e-01, 5.24397375e-01, 4.82195729e-01,
#         9.11764706e-01],
#        [4.66750296e-01, 4.85654010e-01, 4.78733381e-01, 4.59816879e-01,
#         7.05882353e-01],
#        [4.91737891e-01, 4.74922304e-01, 4.87460880e-01, 4.85320151e-01,
#         7.94117647e-01],
#        [4.84387689e-01, 4.94221551e-01, 4.98643004e-01, 4.83580607e-01,
#         8.52941176e-01],
#        [4.94880311e-01, 4.93333381e-01, 4.95229678e-01, 4.93005125e-01,
#         9.70588235e-01],
#        [5.09348615e-01, 4.91625664e-01, 5.30916603e-01, 4.81261810e-01,
#         7.94117647e-01],
#        [5.35276381e-01, 5.14383088e-01, 5.31024046e-01, 5.16905398e-01,
#         7.35294118e-01],
#        [5.78662809e-01, 5.25962951e-01, 6.41760680e-01, 5.39725367e-01,
#         8.23529412e-01],
#        [6.18706170e-01, 5.88382859e-01, 6.14501120e-01, 5.86215320e-01,
#         8.52941176e-01],
#        [5.91615787e-01, 6.20455771e-01, 6.12064262e-01, 6.10012470e-01,
#         8.52941176e-01],
#        [6.06136986e-01, 6.08117039e-01, 6.04047347e-01, 6.09227501e-01,
#         9.41176471e-01],
#        [5.72876649e-01, 6.05052168e-01, 6.07047764e-01, 5.84194411e-01,
#         9.11764706e-01],
#        [5.20283105e-01, 5.76170419e-01, 5.78797371e-01, 5.18256388e-01,
#         8.23529412e-01],
#        [6.39217386e-01, 5.20251066e-01, 6.35023961e-01, 5.25173220e-01,
#         5.58823529e-01],
#        [5.55195989e-01, 6.51614402e-01, 6.42882908e-01, 5.50620435e-01,
#         8.52941176e-01],
#        [5.72372357e-01, 5.54687680e-01, 5.68382287e-01, 5.57379994e-01,
#         6.47058824e-01],
#        [5.71556888e-01, 5.80038206e-01, 5.79139707e-01, 5.75531046e-01,
#         8.23529412e-01],
#        [5.95158376e-01, 5.78347894e-01, 5.94769068e-01, 5.85165075e-01,
#         7.35294118e-01],
#        [6.23173455e-01, 6.24340514e-01, 6.28412649e-01, 6.21842478e-01,
#         8.23529412e-01],
#        [5.68813178e-01, 6.28534845e-01, 6.24020568e-01, 5.86701374e-01,
#         8.82352941e-01],
#        [6.21966937e-01, 5.43653394e-01, 6.23673790e-01, 5.57602835e-01,
#         6.17647059e-01],
#        [6.14694005e-01, 6.27172145e-01, 6.28509893e-01, 6.14664366e-01,
#         7.35294118e-01],
#        [6.39033984e-01, 6.17618873e-01, 6.58638569e-01, 6.32160542e-01,
#         7.35294118e-01],
#        [6.39167613e-01, 6.42439104e-01, 6.39526682e-01, 6.52639504e-01,
#         9.41176471e-01],
#        [6.32935328e-01, 6.45856249e-01, 6.37857220e-01, 6.26205703e-01,
#         9.41176471e-01],
#        [6.01169182e-01, 6.27987072e-01, 6.21466391e-01, 6.02916522e-01,
#         7.35294118e-01],
#        [6.42675839e-01, 6.16637843e-01, 6.62581532e-01, 6.11940538e-01,
#         7.94117647e-01],
#        [6.41272682e-01, 6.45965077e-01, 6.66317251e-01, 6.54499990e-01,
#         9.11764706e-01],
#        [6.39511590e-01, 6.46416815e-01, 6.50929037e-01, 6.46841810e-01,
#         9.70588235e-01],
#        [6.92104952e-01, 6.40928926e-01, 6.96669712e-01, 6.54503242e-01,
#         8.82352941e-01],
#        [7.28092196e-01, 6.95315436e-01, 7.40755239e-01, 7.10868252e-01,
#         9.70588235e-01],
#        [7.66441995e-01, 7.39507253e-01, 7.62320677e-01, 7.49243460e-01,
#         9.41176471e-01],
#        [8.68517227e-01, 7.68330041e-01, 8.69021679e-01, 7.84654770e-01,
#         9.70588235e-01],
#        [1.00000000e+00, 8.78942953e-01, 9.96011055e-01, 8.70757696e-01,
#         1.00000000e+00],
#        [9.62632883e-01, 9.97073787e-01, 9.85554101e-01, 9.88084678e-01,
#         9.11764706e-01],
#        [9.36817764e-01, 9.79380746e-01, 9.77952127e-01, 9.62503981e-01,
#         9.11764706e-01],
#        [9.96656014e-01, 9.50519366e-01, 1.00000000e+00, 9.63367801e-01,
#         9.11764706e-01],
#        [9.77698647e-01, 1.00000000e+00, 9.94727130e-01, 1.00000000e+00,
#         9.41176471e-01],
#        [9.70837748e-01, 9.75295050e-01, 9.76995217e-01, 9.89275349e-01,
#         9.70588235e-01],
#        [8.31833127e-01, 9.77691466e-01, 9.65402007e-01, 8.27093100e-01,
#         9.70588235e-01],
#        [8.33317615e-01, 8.38693437e-01, 8.70003386e-01, 8.25233055e-01,
#         7.64705882e-01]])

# %% [markdown]
# ARIMA

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(final_dataset)

features = scaled_data[:, 1:]
target = scaled_data[:, 0]
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
train_size = int(len(final_dataset_n) * 0.8)

# %%
train, test = final_dataset_n[:train_size], final_dataset_n[train_size:]

# %%
target_train = train[:, 0]
target_test = test[:, 0]

# %%
model = ARIMA(target_train, order=(5,1,0))

model_fit = model.fit()

# %%
forecast = model_fit.forecast(steps=len(test))

# %%
rmse = mean_squared_error(target_test, forecast, squared=False)
print(f"RMSE: {rmse}")
# Out:
# RMSE: 0.22001591392789352

# %% [markdown]
# Random Forest regressor

# %%
random_forest = RandomForestRegressor()

random_forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
rf_predictions = random_forest.predict(X_test)

# %%
rmse = mean_squared_error(y_test, rf_predictions, squared=False)
print(rmse)
# Out:
# 0.03850837226903814

# %% [markdown]
# Gradient Boosting Regressor

# %%
gradient_boosting = GradientBoostingRegressor()

gradient_boosting.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
gb_predictions = gradient_boosting.predict(X_test)

# %%
rmse = mean_squared_error(y_test, gb_predictions, squared=False)

print(rmse)
# Out:
# 0.036759008929800135

# %% [markdown]
# Linear Regression

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(final_dataset)

features = scaled_data[:, 1:]
target = scaled_data[:, 0]

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

model = LinearRegression()
model.fit(X_train, y_train)

predicted_normalized_price = model.predict(X_test)

predicted_prices = scaler.inverse_transform(
    np.concatenate((predicted_normalized_price.reshape(-1, 1), X_test), axis=1))[:, 0]

# %%
rmse = mean_squared_error(y_test, predicted_normalized_price, squared=False)
rmse
# Out:
# 0.011079102552223474

# %%
features_for_prediction = np.array(features[-1]).reshape(1, -1)
predicted_value_normalized = model.predict(features_for_prediction)

# %%
predicted_value_normalized
# Out:
# array([0.84722758])

# %%
predicted_prices = scaler.inverse_transform(
    np.concatenate((predicted_value_normalized.reshape(-1, 1), features_for_prediction), axis=1))[:, 0]

print("Predicted closing prices of the next day:", predicted_prices)
# Out:
# Predicted closing prices of the next day: [41538.90485264]

# %%
latest_closing_price = final_dataset['closing_price'][-1]

# %%
if(latest_closing_price - predicted_prices[0] > 0):
  print('The value is going to decrease')

else:
  print('The value is going to increase')
# Out:
# The value is going to increase

# %% [markdown]
# Logistic Regression

# %%
features = scaled_data[:-1]  # Exclude the last day for prediction
target = (final_dataset['closing_price'].shift(-1) > final_dataset['closing_price']).iloc[:-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=65)
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
predictions = model.predict(X_test)
predictions = [not c for c in predictions]

accuracy = accuracy_score(y_test, predictions)

print("Accuracy =", accuracy*100)
# Out:
# Accuracy = 77.77777777777779

# %%
predictions
# Out:
# [True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False]

# %%
prediction_features = scaled_data[-1].reshape(1, -1)
prediction_result = model.predict(prediction_features)
prediction_result
# Out:
# array([False])

# %%
latest_closing_price = final_dataset['closing_price'][-1]
latest_closing_price
# Out:
# 41286.271108285575

# %%
if prediction_result[-1]:
   print('The value is going to decrease')
else:
  print('The value is going to increase')
# Out:
# The value is going to increase

# %% [markdown]
# # We decided to go with Logistic Regression, which we thought will be a good fit.
